# %%
import imageio
import matplotlib.pyplot as plt

# %%
image = imageio.imread('parrot.jpg')
# Out:
# C:\Users\boga gaming\AppData\Local\Temp\ipykernel_19432\1569472250.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread('parrot.jpg')

# %%
plt.imshow(image)

# %%
print('Type of the image : ' , type(image))
print()
print('Shape of the image : {}'.format(image.shape))
print('Image Height : {}'.format(image.shape[0]))
print('Image Width : {}'.format(image.shape[1]))
print('Dimension of Image : {}'.format(image.ndim))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
#
# Shape of the image : (810, 900, 3)
# Image Height : 810
# Image Width : 900
# Dimension of Image : 3

# %%
print('Image size {}'.format(image.size))
print('Maximum RGB value in this image {}'.format(image.max()))
print('Minimum RGB value in this image {}'.format(image.min()))
# Out:
# Image size 2187000
# Maximum RGB value in this image 255
# Minimum RGB value in this image 0

# %%
print('Value of only R channel {}'.format(image[ 100, 50, 0]))
print('Value of only G channel {}'.format(image[ 100, 50, 1]))
print('Value of only B channel {}'.format(image[ 100, 50, 2]))
# Out:
# Value of only R channel 107
# Value of only G channel 85
# Value of only B channel 64

# %%
plt.title('G channel')
plt.ylabel('Height {}'.format(image.shape[0]))
plt.xlabel('Width {}'.format(image.shape[1]))
# Out:
# Text(0.5, 0, 'Width 900')

# %%
plt.imshow(image[ : , : , 0])
plt.show()
